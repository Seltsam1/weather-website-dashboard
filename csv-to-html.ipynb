# %%
# Dependencies

import pandas as pd

# %%
# Read csv into a a dataframe

weather_data = pd.read_csv('./Resources/cities.csv')

weather_data
# Out:
#      city_id         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          0  provideniya  64.3833 -173.3000     -7.28        82          92
# 1          1       touros  -5.1989  -35.4608     80.60        74          20
# 2          2      rikitea -23.1203 -134.9692     80.11        67          88
# 3          3      salalah  17.0151   54.0924     73.40        60          75
# 4          4    cape town -33.9258   18.4232     69.01        82          20
# ..       ...          ...      ...       ...       ...       ...         ...
# 542      542      chicama  -7.8447  -79.1469     73.40        78          20
# 543      543       riyadh  24.6877   46.7219     66.20        37          12
# 544      544       calama -22.4667  -68.9333     75.20         9           0
# 545      545      lyubech  51.7026   30.6569     24.57        97          99
# 546      546        mutsu  41.2894  141.2169     28.40        74          75
#
#      Wind Speed Country        Date
# ...

# %%
# Reorder columns
weather_data = weather_data[["city_id", "City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]]

# %%
# Convert dataframe to html

html_data = weather_data.to_html

html_data
# Out:
# <bound method DataFrame.to_html of      city_id         City  Cloudiness Country        Date  Humidity      Lat  \
# 0          0  provideniya          92      RU  1611956247        82  64.3833
# 1          1       touros          20      BR  1611956296        74  -5.1989
# 2          2      rikitea          88      PF  1611956297        67 -23.1203
# 3          3      salalah          75      OM  1611956297        60  17.0151
# 4          4    cape town          20      ZA  1611956138        82 -33.9258
# ..       ...          ...         ...     ...         ...       ...      ...
# 542      542      chicama          20      PE  1611956416        78  -7.8447
# 543      543       riyadh          12      SA  1611956170        37  24.6877
# 544      544       calama           0      CL  1611956417         9 -22.4667
# 545      545      lyubech          99      UA  1611956417        97  51.7026
# 546      546        mutsu          75      JP  1611956418        74  41.2894
#
# ...

# %%
# Save html as file in Resources folder

weather_data.to_html(open('./Resources/cities.html', 'w'))
